# %% [markdown]
# ## 0. 설정

# %%
<< mTensor`

# %%
$PreRead = 
  ReplaceAll[#, 
    expr_String :> StringReplace[expr,
    "TMP" -> "mTensor`Private"]] &;

# %%
DefineKind[Alphabet["Greek"], Greek];
DefineKind[ToUpperCase /@ Alphabet[], Capital]

# %%
Tdefine[T, "*"];
Tdefine[f[]]; Tdefine[v, "a"];
Tdefine[A, "-ba"]; Tdefine[B, "ab"];
Tdefine[S, "ba"]; Tdefine[F, "-ba"]

# %% [markdown]
# ## 1. xSort

# %% [markdown]
# ### 1.1 flattenObject

# %% [markdown]
# #### 1.1.1 metricState

# %%
TMP`metricState[la, Kdelta, {}]
# Out:
# {-1, Metricg, 0}

# %%
TMP`metricState[la, BD, {}]
# Out:
# {-1, Metricg, 0}

# %%
TMP`metricState[la, BD, {CovDs -> {BD}}]
# Out:
# {-1, Metricg, 1}

# %%
TMP`metricState[ua, Other, {}]
# Out:
# {1, Null, 0}

# %%
TMP`metricState[la, T, {}]
# Out:
# {-1, Metricg, 1}

# %%
TMP`metricState[-1, T, {}]
# Out:
# {-1, Null, 0}

# %%
TMP`metricState[-1, Other, {}]
# Out:
# {-1, Null, 0}

# %% [markdown]
# #### 1.1.2 reCheckMetricStates

# %%
TMP`reCheckMetricStates[{CD, la}, {A, B, C, D}, {}]
# Out:
# {A, B, C, D}

# %%
TMP`reCheckMetricStates[{CD, 2}, {A, B, C, D}, {}]
# Out:
# {A, B, C, D}

# %%
TMP`reCheckMetricStates[{CD, la}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}, {}]
# Out:
# {A, B, C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}

# %%
TMP`reCheckMetricStates[{CD, -1}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}, {}]
# Out:
# {A, B, C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}

# %%
TMP`reCheckMetricStates[{CD, lA}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}, {}]
# Out:
# {A, B, C, {{D, Null, 0}, {F, Null, 0}, {G, Null, 0}}}

# %%
TMP`reCheckMetricStates[{LD, v}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}, {}]
# Out:
# {A, B, C, {{D, Null, 0}, {F, Null, 0}, {G, Null, 0}}}

# %%
TMP`reCheckMetricStates[{LD, v}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, 
    Metricg, -1}}}, {CovDs -> {LD}}]
# Out:
# {A, B, C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}

# %%
TMP`reCheckMetricStates[{BD, la}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}, {}]
# Out:
# {A, B, C, {{D, Null, 0}, {F, Null, 0}, {G, Null, 0}}}

# %%
TMP`reCheckMetricStates[{BD, la}, {A, B, 
  C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, 
    Metricg, -1}}}, {CovDs -> {BD}}]
# Out:
# {A, B, C, {{D, Metricg, 0}, {F, Metricg, 1}, {G, Metricg, -1}}}

# %% [markdown]
# #### 1.1.3 IndexedOperand

# %%
TMP`flattenObject[T[], {}]
# Out:
# xObject[T[], {T}, {{}, {}, {}, {}}]

# %%
TMP`flattenObject[A[-2, la], {}]
# Out:
# xObject[A[-2, la], {A}, {{-2, la}, {-2, la}, {}, {{-1, Null, 0}, {-1, Metricg, 1}}}]

# %%
TMP`flattenObject[Kdelta[ub, la], {}]
# Out:
# xObject[Kdelta[ub, la], {Kdelta}, {{ub, la}, {ub, la}, {},
#
# >    {{1, Metricg, 0}, {-1, Metricg, 0}}}]

# %% [markdown]
# #### 1.1.4 IndexedOperator

# %% [markdown]
# ##### 1.1.4.1 CD-type

# %%
TMP`flattenObject[CD[la, T[ub, uc]], {}]
# Out:
# xObject[CD[la, T[ub, uc]], {CD, T},
#
# >   {{la, ub, uc}, {la, ub, uc}, {},
#
# >    {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[CD[la, T[ub, ua]], {}]
# Out:
# xObject[CD[la, T[ub, ua]], {CD, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[CD[-1, T[ub, ua]], {}]
# Out:
# xObject[CD[-1, T[ub, ua]], {CD, T},
#
# >   {{-1, ub, ua}, {-1, ub, ua}, {}, {{-1, Null, 0}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[CD[lb, la, T[ub, ua]], {}]
# Out:
# xObject[CD[lb, CD[la, T[ub, ua]]], {CD, CD, T},
#
# >   {{lb, la, ub, ua}, {}, {lb, ub, la, ua},
#
# >    {{-1, Metricg, 1}, {-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[BD[la, T[ub, ua]], {}]
# Out:
# xObject[BD[la, T[ub, ua]], {BD, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 0}, {1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[BD[la, T[ub, ua]], {CovDs -> {BD}}]
# Out:
# xObject[BD[la, T[ub, ua]], {BD, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[CD[lb, BD[la, T[ub, ua]]], {}]
# Out:
# xObject[CD[lb, BD[la, T[ub, ua]]], {CD, BD, T},
#
# >   {{lb, la, ub, ua}, {}, {lb, ub, la, ua},
#
# >    {{-1, Metricg, 1}, {-1, Metricg, 0}, {1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[CD[lb, -1, T[ub, ua]], {}]
# Out:
# xObject[CD[lb, CD[-1, T[ub, ua]]], {CD, CD, T},
#
# >   {{lb, -1, ub, ua}, {-1, ua}, {lb, ub},
#
# >    {{-1, Metricg, 1}, {-1, Null, 0}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %% [markdown]
# ##### 1.1.4.2 LD-type

# %%
TMP`flattenObject[LD[V, T[ub, ua]], {}]
# Out:
# xObject[LD[V, T[ub, ua]], {LD, V, T},
#
# >   {{ub, ua}, {ub, ua}, {}, {{1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[LD[v, T[ub, ua]], {}]
# Out:
# xObject[LD[v, T[ub, ua]], {LD, v, T},
#
# >   {{ub, ua}, {ub, ua}, {}, {{1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[CD[la, LD[v, T[ub, ua]]], {}]
# Out:
# xObject[CD[la, LD[v, T[ub, ua]]], {CD, LD, v, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 1}, {1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[CD[la, LD[v, T[ub, ua]]], {CovDs -> {CD, LD}}]
# Out:
# xObject[CD[la, LD[v, T[ub, ua]]], {CD, LD, v, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]

# %%
TMP`flattenObject[BD[la, LD[v, T[ub, ua]]], {}]
# Out:
# xObject[BD[la, LD[v, T[ub, ua]]], {BD, LD, v, T},
#
# >   {{la, ub, ua}, {ub}, {la, ua}, {{-1, Metricg, 0}, {1, Null, 0}, {1, Null, 0}}}]

# %% [markdown]
# ##### 1.1.4.3 XD-type

# %%
TMP`defineOperator[Lap,
  "\!\(\*SuperscriptBox[\(\[PartialD]\), \(2\)]\)", XD]

# %%
TMP`flattenObject[Lap[T[ub, ua]], {}]
# Out:
# xObject[Lap[T[ub, ua]], {Lap, T}, {{ub, ua}, {ub, ua}, {}, {{1, Null, 0}, {1, Null, 0}}}]

# %%
TMP`flattenObject[Lap[T[ub, ua]], {CovDs -> {CD, Lap}}]
# Out:
# xObject[Lap[T[ub, ua]], {Lap, T}, {{ub, ua}, {ub, ua}, {},
#
# >    {{1, Metricg, 1}, {1, Metricg, 1}}}]

# %% [markdown]
# ##### 1.1.4.4 XP-type

# %%
TMP`defineOperator[oXP, "*", XP]

# %%
(* XP-type is NOT considered. *)
TMP`flattenObject[oXP[T[ub, ua], A[lb, la], v[lc]], {}]
# Out:
# mTensor`Private`$flattenOTHER[oXP[T[ub, ua], A[lb, la], v[lc]]]

# %% [markdown]
# ##### 1.1.4.5 Scalar-functions

# %%
TMP`flattenObject[Tscalar[A[uc, ud] A[ld, lc]], {}]
# Out:
# xObject[Tscalar[A[la, lb] A[ub, ua]], {A[la, lb] A[ub, ua]}, {{}, {}, {}, {}}]

# %%
TMP`flattenObject[Log[A[ud, uc] A[ld, lc]], {}]
# Out:
# xObject[Log[Tscalar[A[la, lb] A[ua, ub]]], {Log, A[la, lb] A[ua, ub]}, {{}, {}, {}, {}}]

# %%
TMP`flattenObject[Tscalar[A[ud, uc] A[lc, ld]]^2, {}]
# Out:
#                                     2
# xObject[Tscalar[A[lc, ld] A[ud, uc]] , {Power, Tscalar[A[lc, ld] A[ud, uc]], 2},
#
# >   {{}, {}, {}, {}}]

# %%
TMP`flattenObject[Tscalar[A[ud, ua] A[ld, la]]^(v[la] v[ua]), {}]
# Out:
#                                     v[la] v[ua]
# xObject[Tscalar[A[ld, la] A[ud, ua]]           ,
#
# >   {Power, Tscalar[A[ld, la] A[ud, ua]], v[la] v[ua]}, {{}, {}, {}, {}}]

# %% [markdown]
# #### 1.1.5 Plus

# %%
TMP`flattenObject[T[] A[lb, la] + B[la, lb], {}]
# Out:
# mTensor`Private`$flattenOTHER[B[la, lb] + A[lb, la] T[]]

# %% [markdown]
# #### 1.1.6 Times

# %%
TMP`flattenObject[T[] A[lb, la], {}]
# Out:
# xTensorTimes[xObject[A[lb, la], {A},
#
# >    {{lb, la}, {lb, la}, {}, {{-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >   xObject[T[], {T}, {{}, {}, {}, {}}]]

# %%
TMP`flattenObject[T[] A[lb, la] B[la, lb], {}]
# Out:
# xTensorTimes[xObject[A[lb, la], {A},
#
# >    {{lb, la}, {lb, la}, {}, {{-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >   xObject[B[la, lb], {B}, {{la, lb}, {la, lb}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}}}], xObject[T[], {T}, {{}, {}, {}, {}}]]

# %% [markdown]
# #### 1.1.7 Others

# %%
TMP`flattenObject[nonT[la, lb], {}]
# Out:
# mTensor`Private`$flattenOTHER[nonT[la, lb]]

# %% [markdown]
# #### 1.1.8 check

# %%
TMP`flattenObject[#, {}] & /@ {A[], A[la], A[lA, lb], A[la, lb]}
# Out:
# {mTensor`Private`errObject[ErrorT[A][]], mTensor`Private`errObject[ErrorT[A][la]],
#
# >   mTensor`Private`errObject[ErrorT[A][lA, lb]],
#
# >   xObject[A[la, lb], {A}, {{la, lb}, {la, lb}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}}}]}

# %%
TMP`flattenObject[#, {}] & /@ {CD[lA, T[ub, uc]], CD[la, T[ub, la]], 
  CD[la, T[ub, ua]]}
# Out:
# {mTensor`Private`errObject[ErrorT[CD][lA, T[ub, uc]]],
#
# >   mTensor`Private`errObject[ErrorT[CD][la, T[ub, la]]],
#
# >   xObject[CD[la, T[ub, ua]], {CD, T},
#
# >    {{la, ub, ua}, {ub}, {la, ua},
#
# >     {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]}

# %%
TMP`flattenObject[#, {}] & /@ {oXP[T[ub, ua], A[lb, la], v[la]], 
  oXP[T[ub, ua], A[lb, lc], v[la]]}
# Out:
# {mTensor`Private`errObject[ErrorT[oXP][T[ub, ua], A[lb, la], v[la]]],
#
# >   mTensor`Private`$flattenOTHER[oXP[T[ub, ua], A[lb, lc], v[la]]]}

# %%
TMP`flattenObject[#, {}] & /@ {T[] A[lb, lA], T[] A[lb, la]}
# Out:
# {xTensorTimes[mTensor`Private`errObject[ErrorT[A][lb, lA]],
#
# >    xObject[T[], {T}, {{}, {}, {}, {}}]],
#
# >   xTensorTimes[xObject[A[lb, la], {A},
#
# >     {{lb, la}, {lb, la}, {}, {{-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >    xObject[T[], {T}, {{}, {}, {}, {}}]]}

# %%
TMP`flattenObject[T[] A[lb, la] B[lC, ld] T[ua, ub], {}]
# Out:
# xTensorTimes[xObject[A[lb, la], {A},
#
# >    {{lb, la}, {lb, la}, {}, {{-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >   mTensor`Private`errObject[ErrorT[B][lC, ld]], xObject[T[], {T}, {{}, {}, {}, {}}],
#
# >   xObject[T[ua, ub], {T}, {{ua, ub}, {ua, ub}, {},
#
# >     {{1, Metricg, 1}, {1, Metricg, 1}}}]]

# %%
TMP`flattenObject[#, {}] & /@ {Tscalar[A[ub, ua] A[lb, ua]], 
  Log[A[ub, ua] A[lb, ua]], (A[ub, ua] A[lb, la])^2, 
  Tscalar[A[ub, ua] A[lb, ua]]^2, Tscalar[A[ub, ua] A[lb, la]]^(
  v[la] v[la])}
# Out:
# {mTensor`Private`errObject[ErrorT[Tscalar][A[lb, ua] A[ub, ua]]],
#
# >   mTensor`Private`errObject[ErrorT[Log][A[lb, ua] A[ub, ua]]],
#
# >   xTensorTimes[mTensor`Private`errObject[ErrorT[Power][A[lb, la], 2]],
#
# >    mTensor`Private`errObject[ErrorT[Power][A[ub, ua], 2]]],
#
# >   mTensor`Private`errObject[ErrorT[Power][Tscalar[A[lb, ua] A[ub, ua]], 2]],
#
#                                                                                2
# >   mTensor`Private`errObject[ErrorT[Power][Tscalar[A[lb, la] A[ub, ua]], v[la] ]]}

# %% [markdown]
# ### 1.2 xSort and xUnSort

# %% [markdown]
# #### 1.2.1 markNoIndex

# %%
TMP`markNoIndex[TMP`flattenObject[T[], {}]]
# Out:
# xNoIndex[xObject[T[], {T}, {{}, {}, {}, {}}]]

# %%
TMP`markNoIndex[
 TMP`flattenObject[T[ua] T[] T[-1] T[2] T[-2] S[ud, uf], {}]]
# Out:
# xTensorTimes[xObject[S[ud, uf], {S},
#
# >    {{ud, uf}, {ud, uf}, {}, {{1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xNoIndex[xObject[T[], {T}, {{}, {}, {}, {}}]],
#
# >   xObject[T[-2], {T}, {{-2}, {-2}, {}, {{-1, Null, 0}}}],
#
# >   xObject[T[-1], {T}, {{-1}, {-1}, {}, {{-1, Null, 0}}}],
#
# >   xObject[T[2], {T}, {{2}, {2}, {}, {{1, Null, 0}}}],
#
# >   xObject[T[ua], {T}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}]]

# %% [markdown]
# #### 1.2.2 objectSort

# %%
TMP`objectSort[TMP`flattenObject[T[-1] T[-2], {}]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[T[-2], {T}, {{-2}, {-2}, {}, {{-1, Null, 0}}}],
#
# >    xObject[T[-1], {T}, {{-1}, {-1}, {}, {{-1, Null, 0}}}]]]

# %%
TMP`objectSort[TMP`flattenObject[T[1] T[2], {}]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[T[1], {T}, {{1}, {1}, {}, {{1, Null, 0}}}],
#
# >    xObject[T[2], {T}, {{2}, {2}, {}, {{1, Null, 0}}}]]]

# %%
TMP`objectSort[TMP`flattenObject[T[-2] T[2], {}]]
# Out:
# xTensorTimes[xObject[T[-2], {T}, {{-2}, {-2}, {}, {{-1, Null, 0}}}],
#
# >   xObject[T[2], {T}, {{2}, {2}, {}, {{1, Null, 0}}}]]

# %% [markdown]
# #### 1.2.3 xSort and xUnSort

# %%
TMP`xSort[v[ua]]
# Out:
# xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}]

# %%
TMP`xUnSort[%]
# Out:
# v[ua]

# %%
TMP`xSort[v[ua] v[ub]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[ub], {v}, {{ub}, {ub}, {}, {{1, Metricg, 1}}}]]]

# %%
TMP`xUnSort[%]
# Out:
# v[ua] v[ub]

# %%
TMP`xSort[T[ua, ub, uc] v[lb] v[lc]]
# Out:
# xTensorTimes[xObject[T[ua, ub, uc], {T},
#
# >    {{ua, ub, uc}, {ua, ub, uc}, {},
#
# >     {{1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xCommutingObjects[xObject[v[lb], {v}, {{lb}, {lb}, {}, {{-1, Metricg, 1}}}],
#
# >    xObject[v[lc], {v}, {{lc}, {lc}, {}, {{-1, Metricg, 1}}}]]]

# %%
TMP`xUnSort[%]
# Out:
# T[ua, ub, uc] v[lb] v[lc]

# %%
TMP`xSort[T[ua, ub, uc] T[ud, lb, lc]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[T[ua, ub, uc], {T},
#
# >     {{ua, ub, uc}, {ua, ub, uc}, {},
#
# >      {{1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >    xObject[T[ud, lb, lc], {T}, {{ud, lb, lc}, {ud, lb, lc}, {},
#
# >      {{1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}}}]]]

# %%
TMP`xUnSort[%]
# Out:
# T[ua, ub, uc] T[ud, lb, lc]

# %% [markdown]
# See mStateOrderItems[]:

# %%
Off[MetricgFlag]

# %%
TMP`xSort[v[ua] v[ub]]
# Out:
# xTensorTimes[mTensor`Private`errObject[ErrorT[v][ua]],
#
# >   mTensor`Private`errObject[ErrorT[v][ub]]]

# %%
TMP`xSort[v[ua] v[lb]]
# Out:
# xTensorTimes[xObject[v[lb], {v}, {{lb}, {lb}, {}, {{-1, Null, 1}}}],
#
# >   mTensor`Private`errObject[ErrorT[v][ua]]]

# %%
TMP`xSort[v[la] v[lb]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[v[la], {v}, {{la}, {la}, {}, {{-1, Null, 1}}}],
#
# >    xObject[v[lb], {v}, {{lb}, {lb}, {}, {{-1, Null, 1}}}]]]

# %%
On[MetricgFlag]

# %%
TMP`xSort[v[ua] v[ub]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[ub], {v}, {{ub}, {ub}, {}, {{1, Metricg, 1}}}]]]

# %%
TMP`xSort[v[ua] v[lb]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[v[lb], {v},
#
# >     {{lb}, {lb}, {}, {{-1, Metricg, 1}}}],
#
# >    xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}]]]

# %%
TMP`xSort[T[ua, ub, uc] BD[la, T[lb, lc]]]
# Out:
# xTensorTimes[xObject[T[ua, ub, uc], {T},
#
# >    {{ua, ub, uc}, {ua, ub, uc}, {},
#
# >     {{1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xObject[BD[la, T[lb, lc]], {BD, T},
#
# >    {{la, lb, lc}, {la, lb, lc}, {}, {{-1, Metricg, 0}, {-1, Null, 0}, {-1, Null, 0}}}]]

# %%
TMP`xSort[BD[ua, T[ub, uc]] BD[la, T[lb, lc]]]
# Out:
# xTensorTimes[xObject[BD[la, T[lb, lc]], {BD, T},
#
# >    {{la, lb, lc}, {la, lb, lc}, {}, {{-1, Metricg, 0}, {-1, Null, 0}, {-1, Null, 0}}}]\
#
# >    , xObject[BD[ua, T[ub, uc]], {BD, T},
#
# >    {{ua, ub, uc}, {ua, ub, uc}, {}, {{1, Metricg, 0}, {1, Null, 0}, {1, Null, 0}}}]]

# %%
TMP`xSort[BD[ua, T[ub, uc]] BD[la, T[lb, lc]], CovDs -> {CD, BD}]
# Out:
# xTensorTimes[xCommutingObjects[xObject[BD[la, T[lb, lc]], {BD, T},
#
# >     {{la, lb, lc}, {la, lb, lc}, {},
#
# >      {{-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >    xObject[BD[ua, T[ub, uc]], {BD, T},
#
# >     {{ua, ub, uc}, {ua, ub, uc}, {},
#
# >      {{1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]]]

# %%
TMP`xSort[BD[ua, f[]] BD[la, f[]]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[BD[la, f[]], {BD, f},
#
# >     {{la}, {la}, {}, {{-1, Metricg, 0}}}],
#
# >    xObject[BD[ua, f[]], {BD, f}, {{ua}, {ua}, {}, {{1, Metricg, 0}}}]]]

# %%
TMP`xSort[BD[ua, f[]] BD[lb, f[]]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[BD[lb, f[]], {BD, f},
#
# >     {{lb}, {lb}, {}, {{-1, Metricg, 0}}}],
#
# >    xObject[BD[ua, f[]], {BD, f}, {{ua}, {ua}, {}, {{1, Metricg, 0}}}]]]

# %%
TMP`defineOperator[someD, "D", XD]

# %%
TMP`xSort[someD[T[ua, ub, uc]] CD[la, T[lb, lc]]]
# Out:
# xTensorTimes[xObject[CD[la, T[lb, lc]], {CD, T},
#
# >    {{la, lb, lc}, {la, lb, lc}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >   xObject[someD[T[ua, ub, uc]], {someD, T},
#
# >    {{ua, ub, uc}, {ua, ub, uc}, {}, {{1, Null, 0}, {1, Null, 0}, {1, Null, 0}}}]]

# %%
TMP`xSort[LD[v, T[ub, lc]] LD[v, T[lb, uc]]]
# Out:
# xTensorTimes[xObject[LD[v, T[lb, uc]], {LD, v, T},
#
# >    {{lb, uc}, {lb, uc}, {}, {{-1, Null, 0}, {1, Null, 0}}}],
#
# >   xObject[LD[v, T[ub, lc]], {LD, v, T},
#
# >    {{ub, lc}, {ub, lc}, {}, {{1, Null, 0}, {-1, Null, 0}}}]]

# %%
TMP`xSort[LD[v, T[ub, lc]] LD[v, T[lb, ua]]]
# Out:
# xTensorTimes[xObject[LD[v, T[lb, ua]], {LD, v, T},
#
# >    {{lb, ua}, {lb, ua}, {}, {{-1, Null, 0}, {1, Null, 0}}}],
#
# >   xObject[LD[v, T[ub, lc]], {LD, v, T},
#
# >    {{ub, lc}, {ub, lc}, {}, {{1, Null, 0}, {-1, Null, 0}}}]]

# %%
TMP`xSort[LD[v, T[ub, lc]] LD[v, T[lb, ua]], CovDs -> {CD, LD}]
# Out:
# xTensorTimes[xCommutingObjects[xObject[LD[v, T[lb, ua]], {LD, v, T},
#
# >     {{lb, ua}, {lb, ua}, {}, {{-1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >    xObject[LD[v, T[ub, lc]], {LD, v, T},
#
# >     {{ub, lc}, {ub, lc}, {}, {{1, Metricg, 1}, {-1, Metricg, 1}}}]]]

# %% [markdown]
# errObject:

# %%
TMP`xSort[Tscalar[T[la, lb]]]
# Out:
# mTensor`Private`errObject[ErrorT[Tscalar][T[la, lb]]]

# %%
TMP`xSort[Log[T[la, lb]]]
# Out:
# mTensor`Private`errObject[ErrorT[Log][T[la, lb]]]

# %%
TMP`xSort /@ {A[], A[la], A[lA, lb], A[la, lb]}
# Out:
# {mTensor`Private`errObject[ErrorT[A][]], mTensor`Private`errObject[ErrorT[A][la]],
#
# >   mTensor`Private`errObject[ErrorT[A][lA, lb]],
#
# >   xObject[A[la, lb], {A}, {{la, lb}, {la, lb}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}}}]}

# %%
TMP`xUnSort /@ %
# Out:
# {ErrorT[A][], ErrorT[A][la], ErrorT[A][lA, lb], A[la, lb]}

# %%
TMP`xSort /@ {CD[lA, T[ub, uc]], CD[la, T[ub, la]], CD[la, T[ub, ua]]}
# Out:
# {mTensor`Private`errObject[ErrorT[CD][lA, T[ub, uc]]],
#
# >   mTensor`Private`errObject[ErrorT[CD][la, T[ub, la]]],
#
# >   xObject[CD[la, T[ub, ua]], {CD, T},
#
# >    {{la, ub, ua}, {ub}, {la, ua},
#
# >     {{-1, Metricg, 1}, {1, Metricg, 1}, {1, Metricg, 1}}}]}

# %%
TMP`xUnSort /@ %
# Out:
# {ErrorT[CD][lA, T[ub, uc]], ErrorT[CD][la, T[ub, la]], CD[la, T[ub, ua]]}

# %% [markdown]
# Any others:

# %%
TMP`xSort[a]
# Out:
# xNoIndex[a]

# %% [markdown]
# ## 2. xSymmetryOf

# %% [markdown]
# ### 2.1 toSlotRules

# %%
TMP`toSlotRules[3, {ua, lb, c_, _, 1, -2}]
# Out:
# {●4 -> ua, ●5 -> lb, ●6 -> c_, ●7 -> _, ●8 -> 1, ●9 -> -2}

# %%
TMP`toSlotRules[3, {}]
# Out:
# {}

# %% [markdown]
# ### 2.2 emptySymmetry

# %%
TMP`emptySymmetry[x]
# Out:
# xSymmetry[0, x, {}, GenSet[]]

# %%
TMP`emptySymmetry[x, {a, b}]
# Out:
# xSymmetry[2, x, {●1 -> a, ●2 -> b}, GenSet[]]

# %% [markdown]
# ### 2.3 displaceSlots

# %%
TMP`displaceSlots[
 GenSet[{Cycles[{{1, 2}}], +1}, {Cycles[{{3, 4}}], +1}], 3]
# Out:
# GenSet[{Cycles[{{4, 5}}], 1}, {Cycles[{{6, 7}}], 1}]

# %%
TMP`xSymmetryOf[RicciCD[la, lb]]
# Out:
# xSymmetry[2, RicciCD[●1, ●2], {●1 -> la, ●2 -> lb}, GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
TMP`displaceSlots[%, 4]
# Out:
# xSymmetry[6, RicciCD[●5, ●6], {●5 -> la, ●6 -> lb}, GenSet[{Cycles[{{5, 6}}], 1}]]

# %% [markdown]
# ### 2.4 commutingCycles

# %%
TMP`commutingCycles[1, 1]
# Out:
# GenSet[]

# %%
TMP`commutingCycles[4, 1]
# Out:
# GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{3, 4}}], 1}]

# %%
TMP`commutingCycles[6, 2]
# Out:
# GenSet[{Cycles[{{1, 3}, {2, 4}}], 1}, {Cycles[{{3, 5}, {4, 6}}], 1}]

# %% [markdown]
# ### 2.5 joinSymmetries

# %%
s1 = xSymmetry[2, 
  T[xSlot[1], xSlot[2]], {xSlot[1] -> A, xSlot[2] -> B}, 
  GenSet[{Cycles[{{1, 2}}], +1}]]
# Out:
# xSymmetry[2, T[●1, ●2], {●1 -> A, ●2 -> B}, GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
s2 = xSymmetry[3, 
  T[xSlot[1], xSlot[2], xSlot[3]], {xSlot[1] -> C, xSlot[2] -> D, 
   xSlot[3] -> F}, GenSet[{Cycles[{{1, 2}}], +1}]]
# Out:
# xSymmetry[3, T[●1, ●2, ●3], {●1 -> C, ●2 -> D, ●3 -> F}, GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
TMP`joinSymmetries[s1, s2]
# Out:
# xSymmetry[5, xTTimes[T[●1, ●2], T[●3, ●4, ●5]],
#
# >   {●1 -> A, ●2 -> B, ●3 -> C, ●4 -> D, ●5 -> F},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], 1}]]

# %%
s3 = TMP`xSymmetryOf[Tscalar[T[la, lb]]^2]
# Out:
#                                2
# xSymmetry[0, Tscalar[T[la, lb]] , {}, GenSet[]]

# %%
TMP`joinSymmetries[s1, s3]
# Out:
#                                                   2
# xSymmetry[2, xTTimes[T[●1, ●2], Tscalar[T[la, lb]] ], {●1 -> A, ●2 -> B},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}]]

# %% [markdown]
# ### 2.6 IndexedOperand

# %%
TMP`xSymmetryOf[RicciCD[A, B]]
# Out:
# xSymmetry[2, RicciCD[●1, ●2], {●1 -> A, ●2 -> B}, GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
TMP`xSymmetryOf[RiemannCD[G, F, D, K]]
# Out:
# xSymmetry[4, RiemannCD[●1, ●2, ●3, ●4], {●1 -> G, ●2 -> F, ●3 -> D, ●4 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}, {Cycles[{{3, 4}}], -1},
#
# >    {Cycles[{{1, 3}, {2, 4}}], 1}]]

# %%
TMP`xSymmetryOf[Tscalar[T[la, lb]]]
# Out:
# xSymmetry[0, Tscalar[T[la, lb]], {}, GenSet[]]

# %%
TMP`xSymmetryOf[Log[T[la, lb]]]
# Out:
# xSymmetry[0, Log[T[la, lb]], {}, GenSet[]]

# %%
TMP`xSymmetryOf[Other]
# Out:
# xSymmetry[0, Other, {}, GenSet[]]

# %% [markdown]
# ### 2.7 IndexedOperator

# %%
TMP`defineOperator[someD, "D", XD]

# %%
TMP`xSymmetryOf[someD[RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[4, someD[RiemannCD[●1, ●2, ●3, ●4]], {●1 -> G, ●2 -> F, ●3 -> D, ●4 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}, {Cycles[{{3, 4}}], -1},
#
# >    {Cycles[{{1, 3}, {2, 4}}], 1}]]

# %% [markdown]
# #### 2.7.1 Symmetries of `CD[la,lb,scalar]`

# %%
TMP`xSymmetryOf[BD[la, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[5, BD[●1, RiemannCD[●2, ●3, ●4, ●5]],
#
# >   {●1 -> la, ●2 -> G, ●3 -> F, ●4 -> D, ●5 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], -1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{2, 4}, {3, 5}}], 1}]]

# %%
TMP`xSymmetryOf[BD[ua, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[5, BD[●1, RiemannCD[●2, ●3, ●4, ●5]],
#
# >   {●1 -> ua, ●2 -> G, ●3 -> F, ●4 -> D, ●5 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], -1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{2, 4}, {3, 5}}], 1}]]

# %%
TMP`xSymmetryOf[BD[ua, RiemannCD[G, F, D, K]], CovDs -> {CD, BD}]
# Out:
# xSymmetry[5, BD[●1, RiemannCD[●2, ●3, ●4, ●5]],
#
# >   {●1 -> ua, ●2 -> G, ●3 -> F, ●4 -> D, ●5 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], -1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{2, 4}, {3, 5}}], 1}]]

# %%
TMP`xSymmetryOf[CD[la, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[5, CD[●1, RiemannCD[●2, ●3, ●4, ●5]],
#
# >   {●1 -> la, ●2 -> G, ●3 -> F, ●4 -> D, ●5 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], -1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{2, 4}, {3, 5}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, CD[lb, RiemannCD[G, F, D, K]]]]
# Out:
# xSymmetry[6, BD[●1, CD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`findIndices /@ {RiemannCD[G, F, D, K], RiemannCD[ug, F, D, K]}
# Out:
# {{}, {ug}}

# %%
NoIndexQ /@ {RiemannCD[G, F, D, K], RiemannCD[ug, F, D, K]}
# Out:
# {True, False}

# %%
TMP`xSymmetryOf[
 CD[la, lb, RiemannCD[G, F, D, K]]]  (* CDs of a scalar *)
# Out:
# xSymmetry[6, CD[●1, CD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[
 CD[la, lb, lc, RiemannCD[G, F, D, K]]]  (* CDs of a scalar *)
# Out:
# xSymmetry[7, CD[●1, CD[●2, CD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[
 CD[la, ub, lc, RiemannCD[G, F, D, K]]](* CDs of a scalar *)
# Out:
# xSymmetry[7, CD[●1, CD[●2, CD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[
 CD[la, lb, lc, RiemannCD[ug, F, D, K]]](* CDs of a non-scalar *)
# Out:
# xSymmetry[7, CD[●1, CD[●2, CD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lc, ●4 -> ug, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TorsionFreeQ[CD] = False;

# %%
(* CDs of a scalar and not torsion-free *)
TMP`xSymmetryOf[CD[la, ub, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[6, CD[●1, CD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TorsionFreeQ[CD] = True;  (* default *)

# %%
(* CDs of a scalar and not torsion-free *)
TMP`xSymmetryOf[CD[la, ub, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[6, CD[●1, CD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %% [markdown]
# #### 2.7.2 Symmetries of `BD[la,lb,someT]`

# %%
Off[CoordinateBasisFlag]

# %%
TMP`xSymmetryOf[BD[la, lb, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
On[CoordinateBasisFlag]

# %%
TMP`xSymmetryOf[BD[la, lb, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[ua, lb, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> ua, ●2 -> lb, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, ub, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, ub, RiemannCD[G, F, D, K]], CovDs -> {CD, BD}]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[ua, lb, RiemannCD[G, F, D, K]], CovDs -> {CD, BD}]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> ua, ●2 -> lb, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[ua, ub, RiemannCD[G, F, D, K]], CovDs -> {CD, BD}]
# Out:
# xSymmetry[6, BD[●1, BD[●2, RiemannCD[●3, ●4, ●5, ●6]]],
#
# >   {●1 -> ua, ●2 -> ub, ●3 -> G, ●4 -> F, ●5 -> D, ●6 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, lb, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{6, 7}}], -1}, {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, ub, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, ub, lc, RiemannCD[G, F, D, K]], 
 CovDs -> {CD, BD}]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{6, 7}}], -1}, {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, lb, uc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> uc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, ub, lc, ld, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> la, ●2 -> ub, ●3 -> lc, ●4 -> ld, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{3, 4}}], 1}, {Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, lb, uc, RiemannCD[G, F, D, K]], 
 CovDs -> {CD, BD}]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> uc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{6, 7}}], -1}, {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, lb, uc, ld, RiemannCD[G, F, D, K]], 
 CovDs -> {CD, BD}]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> uc, ●4 -> ld, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{3, 4}}], 1},
#
# >    {Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1}, {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
CoordinateBasisQ[Greek]
# Out:
# False

# %%
TMP`xSymmetryOf[BD[la, lb, l\[Mu], ld, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lμ, ●4 -> ld, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, l\[Mu], l\[Nu], ld, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> la, ●2 -> lμ, ●3 -> lν, ●4 -> ld, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
TMP`xSymmetryOf[BD[la, l\[Mu], l\[Nu], ld, le, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[9, BD[●1, BD[●2, BD[●3, BD[●4, BD[●5, RiemannCD[●6, ●7, ●8, ●9]]]]]],
#
# >   {●1 -> la, ●2 -> lμ, ●3 -> lν, ●4 -> ld, ●5 -> le, ●6 -> G, ●7 -> F, ●8 -> D,
#
# >    ●9 -> K}, GenSet[{Cycles[{{4, 5}}], 1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{8, 9}}], -1}, {Cycles[{{6, 8}, {7, 9}}], 1}]]

# %%
TMP`defineOperator[PD, "\[ScriptCapitalD]", CD]

# %%
TMP`xSymmetryOf[PD[la, PD[lb, PD[lc, RiemannCD[G, F, D, K]]]]]
# Out:
# xSymmetry[7, PD[●1, PD[●2, PD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> la, ●2 -> lb, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[-1, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[5, BD[●1, RiemannCD[●2, ●3, ●4, ●5]],
#
# >   {●1 -> -1, ●2 -> G, ●3 -> F, ●4 -> D, ●5 -> K},
#
# >   GenSet[{Cycles[{{2, 3}}], -1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{2, 4}, {3, 5}}], 1}]]

# %%
TMP`xSymmetryOf[BD[-1, lB, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> -1, ●2 -> lB, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{4, 5}}], -1}, {Cycles[{{6, 7}}], -1},
#
# >    {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %%
TMP`xSymmetryOf[BD[-1, lB, lc, lA, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> -1, ●2 -> lB, ●3 -> lc, ●4 -> lA, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
TMP`xSymmetryOf[BD[-1, ub, lA, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[8, BD[●1, BD[●2, BD[●3, BD[●4, RiemannCD[●5, ●6, ●7, ●8]]]]],
#
# >   {●1 -> -1, ●2 -> ub, ●3 -> lA, ●4 -> lc, ●5 -> G, ●6 -> F, ●7 -> D, ●8 -> K},
#
# >   GenSet[{Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}]]

# %%
(* indexKindProper[-1] != DefaultKind *)
TMP`xSymmetryOf[BD[-1, -2, lc, RiemannCD[G, F, D, K]]]
# Out:
# xSymmetry[7, BD[●1, BD[●2, BD[●3, RiemannCD[●4, ●5, ●6, ●7]]]],
#
# >   {●1 -> -1, ●2 -> -2, ●3 -> lc, ●4 -> G, ●5 -> F, ●6 -> D, ●7 -> K},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}, {Cycles[{{4, 5}}], -1},
#
# >    {Cycles[{{6, 7}}], -1}, {Cycles[{{4, 6}, {5, 7}}], 1}]]

# %% [markdown]
# ### 2.8 Term

# %%
TMP`xSymmetryOf[T[la, lb] A[lc, ld]]
# Out:
# xSymmetry[4, xTTimes[A[●1, ●2], T[●3, ●4]], {●1 -> lc, ●2 -> ld, ●3 -> la, ●4 -> lb},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}]]

# %%
TMP`xSort[A[uc, ub] RiemannCD[lj, lm, ll, lk]]
# Out:
# xTensorTimes[xObject[A[uc, ub], {A},
#
# >    {{uc, ub}, {uc, ub}, {}, {{1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xObject[RiemannCD[lj, lm, ll, lk], {RiemannCD},
#
# >    {{lj, lm, ll, lk}, {lj, lm, ll, lk}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}}}]]

# %%
TMP`xSymmetryOf[A[uc, ub] RiemannCD[lj, lm, ll, lk]]
# Out:
# xSymmetry[6, xTTimes[A[●1, ●2], RiemannCD[●3, ●4, ●5, ●6]],
#
# >   {●1 -> uc, ●2 -> ub, ●3 -> lj, ●4 -> lm, ●5 -> ll, ●6 -> lk},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}]]

# %% [markdown]
# ### 2.9 xCommutingObjects

# %%
TMP`xSymmetryOf[v[la] v[lb]]
# Out:
# xSymmetry[2, xTTimes[v[●1], v[●2]], {●1 -> la, ●2 -> lb}, GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
TMP`xSymmetryOf[v[la] v[1] v[ub]]
# Out:
# xSymmetry[3, xTTimes[v[●1], v[●2], v[●3]], {●1 -> la, ●2 -> ub, ●3 -> 1},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}]]

# %%
term = T[la, lb] A[ub, uc] S[lc, uj] T[ld, lf] v[ud] v[uf] v[
   ua] RiemannCD[lj, lk, ll, lm]
# Out:
# A[ub, uc] RiemannCD[lj, lk, ll, lm] S[lc, uj] T[la, lb] T[ld, lf] v[ua] v[ud] v[uf]

# %%
TMP`findFreeIndices[term]
# Out:
# {lk, ll, lm}

# %%
TMP`xSort[v[ua] v[ub] v[uc]]
# Out:
# xTensorTimes[xCommutingObjects[xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[ub], {v}, {{ub}, {ub}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[uc], {v}, {{uc}, {uc}, {}, {{1, Metricg, 1}}}]]]

# %%
TMP`xSymmetryOf[v[ua] v[ub] v[uc]]
# Out:
# xSymmetry[3, xTTimes[v[●1], v[●2], v[●3]], {●1 -> ua, ●2 -> ub, ●3 -> uc},
#
# >   GenSet[{Cycles[{{1, 2}}], 1}, {Cycles[{{2, 3}}], 1}]]

# %%
TMP`xSort[term]
# Out:
# xTensorTimes[xObject[A[ub, uc], {A},
#
# >    {{ub, uc}, {ub, uc}, {}, {{1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xObject[RiemannCD[lj, lk, ll, lm], {RiemannCD},
#
# >    {{lj, lk, ll, lm}, {lj, lk, ll, lm}, {},
#
# >     {{-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >   xObject[S[lc, uj], {S}, {{lc, uj}, {lc, uj}, {},
#
# >     {{-1, Metricg, 1}, {1, Metricg, 1}}}],
#
# >   xCommutingObjects[xObject[T[la, lb], {T},
#
# >     {{la, lb}, {la, lb}, {}, {{-1, Metricg, 1}, {-1, Metricg, 1}}}],
#
# >    xObject[T[ld, lf], {T}, {{ld, lf}, {ld, lf}, {},
#
# >      {{-1, Metricg, 1}, {-1, Metricg, 1}}}]],
#
# >   xCommutingObjects[xObject[v[ua], {v}, {{ua}, {ua}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[ud], {v}, {{ud}, {ud}, {}, {{1, Metricg, 1}}}],
#
# >    xObject[v[uf], {v}, {{uf}, {uf}, {}, {{1, Metricg, 1}}}]]]

# %%
TMP`xSymmetryOf[term]
# Out:
# xSymmetry[15, xTTimes[A[●1, ●2], RiemannCD[●3, ●4, ●5, ●6], S[●7, ●8], T[●9, ●10],
#
# >    T[●11, ●12], v[●13], v[●14], v[●15]],
#
# >   {●1 -> ub, ●2 -> uc, ●3 -> lj, ●4 -> lk, ●5 -> ll, ●6 -> lm, ●7 -> lc, ●8 -> uj,
#
# >    ●9 -> la, ●10 -> lb, ●11 -> ld, ●12 -> lf, ●13 -> ua, ●14 -> ud, ●15 -> uf},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}, {Cycles[{{3, 4}}], -1}, {Cycles[{{5, 6}}], -1},
#
# >    {Cycles[{{3, 5}, {4, 6}}], 1}, {Cycles[{{7, 8}}], 1},
#
# >    {Cycles[{{9, 11}, {10, 12}}], 1}, {Cycles[{{13, 14}}], 1}, {Cycles[{{14, 15}}], 1}]]

# %%
TMP`xSymmetryOf[
 A[uc, um] RiemannCD[lj, lm, ll, ld] B[la, lb] T[lc, lj] v[ua] v[ub]]
# Out:
# xSymmetry[12, xTTimes[A[●1, ●2], B[●3, ●4], RiemannCD[●5, ●6, ●7, ●8], T[●9, ●10],
#
# >    v[●11], v[●12]], {●1 -> uc, ●2 -> um, ●3 -> la, ●4 -> lb, ●5 -> lj, ●6 -> lm,
#
# >    ●7 -> ll, ●8 -> ld, ●9 -> lc, ●10 -> lj, ●11 -> ua, ●12 -> ub},
#
# >   GenSet[{Cycles[{{1, 2}}], -1}, {Cycles[{{5, 6}}], -1}, {Cycles[{{7, 8}}], -1},
#
# >    {Cycles[{{5, 7}, {6, 8}}], 1}, {Cycles[{{11, 12}}], 1}]]
