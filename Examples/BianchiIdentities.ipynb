# %% [markdown]
# # Bianchi Identities in SpaceTime with Torsion

# %% [markdown]
# ## 설정

# %%
<< mTensor`

# %%
On[CoordinateBasisFlag[DefaultKind]]  (* default *)

# %%
TorsionFreeQ[CD] = False;  (* not default *)

# %% [markdown]
# ## First Kind

# %% [markdown]
# $$
#   R_{[abc]}^{\ \ \ \ \ \ \ \ d}
#   = -\nabla_{[a} t_{bc]}^{\ \ \ \ d}
#   + t_{[ab}^{\ \ \ \ p} t_{c]p}^{\ \ \ \ d}
# $$

# %%
RiemannCD[la, lb, lc, ud]
# Out:
# RiemannCD[la, lb, lc, ud]

# %%
AntisymmetrizeIndices[{la, lb, lc}, %]
# Out:
# RiemannCD[la, lb, lc, ud]   RiemannCD[la, lc, lb, ud]   RiemannCD[lb, la, lc, ud]
# ------------------------- - ------------------------- - ------------------------- +
#             6                           6                           6
#
#     RiemannCD[lb, lc, la, ud]   RiemannCD[lc, la, lb, ud]   RiemannCD[lc, lb, la, ud]
# >   ------------------------- + ------------------------- - -------------------------
#                 6                           6                           6

# %%
% // RiemannToGamma
# Out:
# -BD[la, GammaCD[lb, lc, ud]]   BD[la, GammaCD[lc, lb, ud]]
# ---------------------------- + --------------------------- +
#              3                              3
#
#     BD[lb, GammaCD[la, lc, ud]]   BD[lb, GammaCD[lc, la, ud]]
# >   --------------------------- - --------------------------- -
#                  3                             3
#
#     BD[lc, GammaCD[la, lb, ud]]   BD[lc, GammaCD[lb, la, ud]]
# >   --------------------------- + --------------------------- -
#                  3                             3
#
#     GammaCD[la, le, ud] GammaCD[lb, lc, ue]   GammaCD[la, lc, ue] GammaCD[lb, le, ud]
# >   --------------------------------------- + --------------------------------------- -
#                        3                                         3
#
#     GammaCD[lb, le, ud] GammaCD[lc, la, ue]   GammaCD[la, le, ud] GammaCD[lc, lb, ue]
# >   --------------------------------------- + --------------------------------------- -
# ...

# %%
% // GammaToMetric
# Out:
# -BD[la, Torsion[lb, lc, ud]]   BD[la, Torsion[lc, lb, ud]]
# ---------------------------- + --------------------------- +
#              6                              6
#
#     BD[lb, Torsion[la, lc, ud]]   BD[lb, Torsion[lc, la, ud]]
# >   --------------------------- - --------------------------- -
#                  6                             6
#
#     BD[lc, Torsion[la, lb, ud]]   BD[lc, Torsion[lb, la, ud]]
# >   --------------------------- + --------------------------- +
#                  6                             6
#
#     BD[lc, Metricg[ud, ue]] BD[le, Metricg[la, lb]]
# >   ----------------------------------------------- -
#                            6
#
#     BD[lb, Metricg[ud, ue]] BD[le, Metricg[la, lc]]
# >   ----------------------------------------------- -
#                            6
#
#     BD[lc, Metricg[ud, ue]] BD[le, Metricg[lb, la]]
# >   ----------------------------------------------- +
#                            6
#
# ...

# %%
lhsRc = %;

# %%
-CD[la, Torsion[lb, lc, ud]] + Torsion[la, lb, ue] Torsion[lc, le, ud]
# Out:
# -CD[la, Torsion[lb, lc, ud]] + Torsion[la, lb, ue] Torsion[lc, le, ud]

# %%
AntisymmetrizeIndices[{la, lb, lc}, %]
# Out:
# -CD[la, Torsion[lb, lc, ud]]   CD[la, Torsion[lc, lb, ud]]
# ---------------------------- + --------------------------- +
#              6                              6
#
#     CD[lb, Torsion[la, lc, ud]]   CD[lb, Torsion[lc, la, ud]]
# >   --------------------------- - --------------------------- -
#                  6                             6
#
#     CD[lc, Torsion[la, lb, ud]]   CD[lc, Torsion[lb, la, ud]]
# >   --------------------------- + --------------------------- +
#                  6                             6
#
#     Torsion[la, le, ud] Torsion[lb, lc, ue]   Torsion[la, lc, ue] Torsion[lb, le, ud]
# >   --------------------------------------- - --------------------------------------- +
#                        6                                         6
#
#     Torsion[lb, le, ud] Torsion[lc, la, ue]   Torsion[la, le, ud] Torsion[lc, lb, ue]
# >   --------------------------------------- - --------------------------------------- +
# ...

# %%
% // CDtoGamma
# Out:
# -BD[la, Torsion[lb, lc, ud]]   BD[la, Torsion[lc, lb, ud]]
# ---------------------------- + --------------------------- +
#              6                              6
#
#     BD[lb, Torsion[la, lc, ud]]   BD[lb, Torsion[lc, la, ud]]
# >   --------------------------- - --------------------------- -
#                  6                             6
#
#     BD[lc, Torsion[la, lb, ud]]   BD[lc, Torsion[lb, la, ud]]
# >   --------------------------- + --------------------------- -
#                  6                             6
#
#     GammaCD[lc, le, ud] Torsion[la, lb, ue]   GammaCD[lb, le, ud] Torsion[la, lc, ue]
# >   --------------------------------------- + --------------------------------------- -
#                        6                                         6
#
#     GammaCD[lb, lc, ue] Torsion[la, le, ud]   GammaCD[lc, lb, ue] Torsion[la, le, ud]
# >   --------------------------------------- + --------------------------------------- +
# ...

# %%
% // GammaToMetric
# Out:
# -BD[la, Torsion[lb, lc, ud]]   BD[la, Torsion[lc, lb, ud]]
# ---------------------------- + --------------------------- +
#              6                              6
#
#     BD[lb, Torsion[la, lc, ud]]   BD[lb, Torsion[lc, la, ud]]
# >   --------------------------- - --------------------------- -
#                  6                             6
#
#     BD[lc, Torsion[la, lb, ud]]   BD[lc, Torsion[lb, la, ud]]
# >   --------------------------- + --------------------------- -
#                  6                             6
#
#     BD[lc, Metricg[le, lf]] Metricg[ud, uf] Torsion[la, lb, ue]
# >   ----------------------------------------------------------- -
#                                 12
#
#     BD[le, Metricg[lc, lf]] Metricg[ud, uf] Torsion[la, lb, ue]
# >   ----------------------------------------------------------- +
#                                 12
#
#     BD[lf, Metricg[lc, le]] Metricg[ud, uf] Torsion[la, lb, ue]
# ...

# %%
rhsRc = %;

# %%
expr = lhsRc - rhsRc
# Out:
# BD[lc, Metricg[ud, ue]] BD[le, Metricg[la, lb]]
# ----------------------------------------------- -
#                        6
#
#     BD[lb, Metricg[ud, ue]] BD[le, Metricg[la, lc]]
# >   ----------------------------------------------- -
#                            6
#
#     BD[lc, Metricg[ud, ue]] BD[le, Metricg[lb, la]]
# >   ----------------------------------------------- +
#                            6
#
#     BD[la, Metricg[ud, ue]] BD[le, Metricg[lb, lc]]
# >   ----------------------------------------------- +
#                            6
#
#     BD[lb, Metricg[ud, ue]] BD[le, Metricg[lc, la]]
# >   ----------------------------------------------- -
#                            6
#
#     BD[la, Metricg[ud, ue]] BD[le, Metricg[lc, lb]]
# >   ----------------------------------------------- +
#                            6
#
#     BD[la, BD[le, Metricg[lb, lc]]] Metricg[ud, ue]
# >   ----------------------------------------------- -
#                            6
#
# ...

# %%
expr // TindexSort
# Out:
# BD[lf, Metricg[la, lc]] BD[lg, Metricg[lb, le]] Metricg[ud, ug] Metricg[ue, uf]
# ------------------------------------------------------------------------------- -
#                                       12
#
#     BD[lf, Metricg[lb, le]] BD[lg, Metricg[la, lc]] Metricg[ud, uf] Metricg[ue, ug]
# >   -------------------------------------------------------------------------------
#                                           12

# %%
% // Tsimplify
# Out:
# 0

# %% [markdown]
# ## Second Kind

# %% [markdown]
# $$
#   \nabla_{[a} R_{bc]d}^{\ \ \ \ \ \ \ e}
#   = t_{[ab}^{\ \ \ \ \ p} R_{c]pd}^{\ \ \ \ \ \ \ e}
# $$

# %%
CD[la, RiemannCD[lb, lc, ld, ue]]
# Out:
# CD[la, RiemannCD[lb, lc, ld, ue]]

# %%
AntisymmetrizeIndices[{la, lb, lc}, %]
# Out:
# CD[la, RiemannCD[lb, lc, ld, ue]]   CD[la, RiemannCD[lc, lb, ld, ue]]
# --------------------------------- - --------------------------------- -
#                 6                                   6
#
#     CD[lb, RiemannCD[la, lc, ld, ue]]   CD[lb, RiemannCD[lc, la, ld, ue]]
# >   --------------------------------- + --------------------------------- +
#                     6                                   6
#
#     CD[lc, RiemannCD[la, lb, ld, ue]]   CD[lc, RiemannCD[lb, la, ld, ue]]
# >   --------------------------------- - ---------------------------------
#                     6                                   6

# %%
% // CDtoGamma
# Out:
# BD[la, RiemannCD[lb, lc, ld, ue]]   BD[la, RiemannCD[lc, lb, ld, ue]]
# --------------------------------- - --------------------------------- -
#                 6                                   6
#
#     BD[lb, RiemannCD[la, lc, ld, ue]]   BD[lb, RiemannCD[lc, la, ld, ue]]
# >   --------------------------------- + --------------------------------- +
#                     6                                   6
#
#     BD[lc, RiemannCD[la, lb, ld, ue]]   BD[lc, RiemannCD[lb, la, ld, ue]]
# >   --------------------------------- - --------------------------------- +
#                     6                                   6
#
#     GammaCD[lc, lf, ue] RiemannCD[la, lb, ld, uf]
# >   --------------------------------------------- -
#                           6
#
#     GammaCD[lc, ld, uf] RiemannCD[la, lb, lf, ue]
# >   --------------------------------------------- -
#                           6
#
#     GammaCD[lb, lf, ue] RiemannCD[la, lc, ld, uf]
# ...

# %%
% // RiemannToGamma
# Out:
# -BD[la, BD[lb, GammaCD[lc, ld, ue]]]   BD[la, BD[lc, GammaCD[lb, ld, ue]]]
# ------------------------------------ + ----------------------------------- +
#                  3                                      3
#
#     BD[lb, BD[la, GammaCD[lc, ld, ue]]]   BD[lb, BD[lc, GammaCD[la, ld, ue]]]
# >   ----------------------------------- - ----------------------------------- -
#                      3                                     3
#
#     BD[lc, BD[la, GammaCD[lb, ld, ue]]]   BD[lc, BD[lb, GammaCD[la, ld, ue]]]
# >   ----------------------------------- + ----------------------------------- -
#                      3                                     3
#
#     BD[lc, GammaCD[lf, ld, ue]] GammaCD[la, lb, uf]
# >   ----------------------------------------------- +
#                            3
#
#     BD[lf, GammaCD[lc, ld, ue]] GammaCD[la, lb, uf]
# >   ----------------------------------------------- +
#                            3
#
# ...

# %%
lhsRc = GammaToMetric[%];

# %%
Torsion[la, lb, uf] RiemannCD[lc, lf, ld, ue]
# Out:
# RiemannCD[lc, lf, ld, ue] Torsion[la, lb, uf]

# %%
AntisymmetrizeIndices[{la, lb, lc}, %]
# Out:
# RiemannCD[lc, lf, ld, ue] Torsion[la, lb, uf]
# --------------------------------------------- -
#                       6
#
#     RiemannCD[lb, lf, ld, ue] Torsion[la, lc, uf]
# >   --------------------------------------------- -
#                           6
#
#     RiemannCD[lc, lf, ld, ue] Torsion[lb, la, uf]
# >   --------------------------------------------- +
#                           6
#
#     RiemannCD[la, lf, ld, ue] Torsion[lb, lc, uf]
# >   --------------------------------------------- +
#                           6
#
#     RiemannCD[lb, lf, ld, ue] Torsion[lc, la, uf]
# >   --------------------------------------------- -
#                           6
#
#     RiemannCD[la, lf, ld, ue] Torsion[lc, lb, uf]
# >   ---------------------------------------------
#                           6

# %%
% // RiemannToGamma
# Out:
# -(BD[lc, GammaCD[lf, ld, ue]] Torsion[la, lb, uf])
# -------------------------------------------------- +
#                         6
#
#     BD[lf, GammaCD[lc, ld, ue]] Torsion[la, lb, uf]
# >   ----------------------------------------------- -
#                            6
#
#     GammaCD[lc, lg, ue] GammaCD[lf, ld, ug] Torsion[la, lb, uf]
# >   ----------------------------------------------------------- +
#                                  6
#
#     GammaCD[lc, ld, ug] GammaCD[lf, lg, ue] Torsion[la, lb, uf]
# >   ----------------------------------------------------------- +
#                                  6
#
#     BD[lb, GammaCD[lf, ld, ue]] Torsion[la, lc, uf]
# >   ----------------------------------------------- -
#                            6
#
#     BD[lf, GammaCD[lb, ld, ue]] Torsion[la, lc, uf]
# >   ----------------------------------------------- +
#                            6
#
#     GammaCD[lb, lg, ue] GammaCD[lf, ld, ug] Torsion[la, lc, uf]
# ...

# %%
rhsRc = GammaToMetric[%];

# %%
(* large terms and long evaluation *)
expr = lhsRc - rhsRc // TindexSort // ResetDummies // Absorbg;

# %%
Length[List @@ expr]
# Out:
# 2534

# %%
expr // Tsimplify
# Out:
# -(BD[lb, Metricg[ld, lf]] BD[lc, Metricg[lg, lh]] BD[ue, Metricg[la, li]]
#
# >       Metricg[uf, uh] Metricg[ug, ui]) / 24 +
#
# >   (BD[la, Metricg[ld, lf]] BD[lc, Metricg[lg, lh]] BD[ue, Metricg[lb, li]]
#
# >      Metricg[uf, uh] Metricg[ug, ui]) / 24 -
#
# >   (BD[la, Metricg[ld, lf]] BD[lb, Metricg[lg, lh]] BD[ue, Metricg[lc, li]]
#
# >      Metricg[uf, uh] Metricg[ug, ui]) / 24 -
#
# >   (BD[lb, Metricg[lf, lg]] BD[lc, Metricg[ld, lh]] BD[ue, Metricg[la, li]]
#
# >      Metricg[ug, ui] Metricg[uh, uf]) / 24 +
#
# >   (BD[lc, Metricg[lf, lg]] BD[ld, Metricg[lb, lh]] BD[ue, Metricg[la, li]]
#
# >      Metricg[ug, ui] Metricg[uh, uf]) / 24 -
#
# >   (BD[lb, Metricg[lf, lg]] BD[ld, Metricg[lc, lh]] BD[ue, Metricg[la, li]]
#
# >      Metricg[ug, ui] Metricg[uh, uf]) / 24 +
#
# >   (BD[la, Metricg[lf, lg]] BD[lc, Metricg[ld, lh]] BD[ue, Metricg[lb, li]]
#
# >      Metricg[ug, ui] Metricg[uh, uf]) / 24 -
#
# ...

# %%
PutMetric[%, ue]
# Out:
# -(BD[lb, Metricg[ld, lf]] BD[lc, Metricg[lg, lh]] BD[lj, Metricg[la, li]]
#
# >       Metricg[ue, uj] Metricg[uf, uh] Metricg[ug, ui]) / 24 +
#
# >   (BD[la, Metricg[ld, lf]] BD[lc, Metricg[lg, lh]] BD[lj, Metricg[lb, li]]
#
# >      Metricg[ue, uj] Metricg[uf, uh] Metricg[ug, ui]) / 24 -
#
# >   (BD[la, Metricg[ld, lf]] BD[lb, Metricg[lg, lh]] BD[lj, Metricg[lc, li]]
#
# >      Metricg[ue, uj] Metricg[uf, uh] Metricg[ug, ui]) / 24 -
#
# >   (BD[lb, Metricg[lf, lg]] BD[lc, Metricg[ld, lh]] BD[lj, Metricg[la, li]]
#
# >      Metricg[ue, uj] Metricg[ug, ui] Metricg[uh, uf]) / 24 +
#
# >   (BD[lc, Metricg[lf, lg]] BD[ld, Metricg[lb, lh]] BD[lj, Metricg[la, li]]
#
# >      Metricg[ue, uj] Metricg[ug, ui] Metricg[uh, uf]) / 24 -
#
# >   (BD[lb, Metricg[lf, lg]] BD[ld, Metricg[lc, lh]] BD[lj, Metricg[la, li]]
#
# >      Metricg[ue, uj] Metricg[ug, ui] Metricg[uh, uf]) / 24 +
#
# >   (BD[la, Metricg[lf, lg]] BD[lc, Metricg[ld, lh]] BD[lj, Metricg[lb, li]]
#
# ...

# %%
% // Tsimplify
# Out:
# 0
